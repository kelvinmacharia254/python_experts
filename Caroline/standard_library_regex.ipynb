# %% [markdown]
# # Standrad Libraries in python
# - Standard libraries in python is a collection of built in modules and packages that comes bundled with python.
# - These tools provide ready to use tools and functionalities, so you don't need to install anything extra to use them.
# - They support common programming tasks such as file handling, regular expressions, math operations, data serialization etc.
# - You just need to import them them to use them e.g import math, import re etc
# - they save developmental time and promotes best practices.

# %% [markdown]
# ### Examples of standard Libraries
# | Module  | Description |
# |---|---|
# | Math| provides mathematical functions like pi, sqrt()|
# | datetime | Works with dates and times |
# |OS | Interacts with operating system like file paths, directories etc |
# | re | regular expressions matching and text searching |
# | collections | specialized data structures like counter, deque, defaultdict |
# | Statistics | performs statistical calculations like mean, median, and mode
# | itertools | tools for efficient looping and combinations
# |json | encode and decode json data
# | time | time related fuctions like delays and timestamps
# | sys | Access system specific parameters and functions
# |random | generate random numbers and choices
# | http | tools for working with HTTP(like http.client, http.server)

# %% [markdown]
# #### EXTRA: Explanation on creating table above using markdown
# - The `|` (pipe) symbol separates columns
# - the `---`(three hyphens) on the second line creates a separator between the header and the table of the body and indictates that its a table.
# - Inline code snippets: use backticks (` `) for code snippet within a sentence
# - Multiline code snippters: Use tripple backticks at start, on a new line and end of the code, on a new line(```   ```)
#
#
# - Example of inline code
# `Hello World`
# - Example of multiline code
# ```
# def hello_world():
#     print("Hello World")
# ```

# %% [markdown]
# #### Examples using standard Libraries
#
# ```
# import math
# print(math.sqrt(25)) #output: 5.0
# ```

# %% [markdown]
# ### What are Third Party libraries
# - Third- party libraries in python are external packages or modules that are not included int he standard Python distribution.
# - They are created by the python community and other developers to extend the Python capabilities especially in specialized fields like data science, web development, machine learning, game development and more.
# - they are not built in and you need to install them separately(usually using pip)
# - they are usually more powerful or specialized than standard libraries
# - They are usually available from the Python Package Index(PyPI)

# %% [markdown]
# #### Example using Third-party libraries
# - `pip install numpy as np` : goes ahead to install numpy and its dependecies
# -  Numpy is used for numerical computing. much faster than import math which is a standard Library. processes arrays faster. Used for linear algebra and statistics. Random number generation etc. has good memory usage.
# - `pip install library_name`
#
# - **Example of Popular Third-party Libraries**
#
# | Library | Purpose |
# |---|---|
# | Numpy | numerical computing, arrays, matrices |
# | Pandas| Data analysis and manipulation|
# | Matplotlib/Seaborn|Data Visualization |
# | Requests| making http requests easily
# | Flask/Django| web development frameworks
# | Scikit-learn| machine-learning
# | TensorFlow/Pytorch| deep learning and AI
# |Beautiful Soup/Scrapy| Web scrapping|
# |OpenCV | computer vision
# | SQLAlchemy | Database ORM(object relational mapping)

# %% [markdown]
# ### Inspecting a library
# - you can inpect a library using `dir()`
# - Example: `dir(math)` : helps to list methods inside math
# - `help(math.pow)`: give explanation on the fuctionality of `.pow`
# - `math.pow.___doc___` :returns a docstring

# %%
#inspecting math library
import math
dir(math) #lists methods in math
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
help(math.pow) # shows how to use power
# Out:
# Help on built-in function pow in module math:
#
# pow(x, y, /)
#     Return x**y (x to the power of y).

# %%
print(math.pow.__doc__) #shows doctsring #use double underscore(dunder)
# Out:
# Return x**y (x to the power of y).

# %% [markdown]
# # String Matching
# - String matching in python refers to a process of **finfing whether a specific sequence of characters(a pattern)** exists within another string(the text).
# - it is commonly used in searching, filtering or validating a text
# - can be used to check if a substring is part of an input
# - string matching is a core concept in python(programming in general) e.g for checking valid telephone numbers, valid address etc.
