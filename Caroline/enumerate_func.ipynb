# %% [markdown]
# # Python Enumerate ()
# - enumerate() functions adds a counter to an iterable and returns it.
#  - **Syntax of enumerate()**
#  ```
#  enumerate(iterable, start=0)
#  ```
#  -enumerate() takes two arguments:
#     - *iterable*- a sequence, an iterator or objects that support iteration
#     - *start*(optional) - enumerate() starts counting from this number. if start is omitted, 0 is taken as a start.

# %% [markdown]
# ### Examples showing workings of Enumerate()

# %%
grocery = ['bread', 'milk', 'butter']
enumerateGrocery = enumerate(grocery)

print(type(enumerateGrocery))

# converting to list
print(list(enumerateGrocery))

# changing the default counter
enumerateGrocery = enumerate(grocery, 10)
print(list(enumerateGrocery))
# Out:
# <class 'enumerate'>
# [(0, 'bread'), (1, 'milk'), (2, 'butter')]
# [(10, 'bread'), (11, 'milk'), (12, 'butter')]

# %% [markdown]
# ### Looping over an enumerate object

# %%
grocery = ['bread', 'milk', 'butter']

# Loop through the enumerate(grocery) result
for item in enumerate(grocery):
    print(item)

print()

# Loop through the enumerate(grocery) result with custom start value
for count, item in enumerate(grocery):
    print(count, item)

print()

# Loop through the enumerate(grocery) result with a custom start value (100)
for count, item in enumerate(grocery, 100):
    print(count, item)
# Out:
# (0, 'bread')
# (1, 'milk')
# (2, 'butter')
#
# 0 bread
# 1 milk
# 2 butter
#
# 100 bread
# 101 milk
# 102 butter

# %% [markdown]
# - The **count** parameter in the **enumerate()** function is an optional parameter that allows you to specify the starting value of the index. By default, the index starts at 0, but if you provide a value for count, the index will start from that specified value.
